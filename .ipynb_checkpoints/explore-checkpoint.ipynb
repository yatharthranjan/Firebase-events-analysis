# %% [markdown]
# First `import` the dependencies. We are using dask distributed client to run the program on dask worker nodes. Edit the `dask_client.py` file to change the options for the dask scheduler

# %%
#!/usr/bin/env python3

import dask.dataframe as df
from dask.distributed import Client, progress

# %% [markdown]
# Next we read the bigquery export from the json file.

# %%
def read_json_as_dataframe(path):
    return df.read_json(path)

client = Client('10.200.107.9:8786')
client.restart()
# , n_workers=3, threads_per_worker=4, memory_limit='10GB')
client.get_versions(check=True)
json_data = read_json_as_dataframe('/home/ubuntu/data/json/bq-results-20190611.json')

# %% [markdown]
# Now lets explore and see the data types and print the head

# %%
json_data.head()

# %%
json_data.dtypes
# Out:
# app_info                          object
# device                            object
# event_name                        object
# event_params                      object
# event_previous_timestamp         float64
# event_server_timestamp_offset      int64
# event_timestamp                    int64
# geo                               object
# user_first_touch_timestamp         int64
# user_properties                   object
# user_pseudo_id                    object
# project_id                        object
# subject_id                        object
# source_id                         object
# human_readable_id                 object
# enrolment_date                    object
# first_open_time                    int64
# firebase_event_origin             object
# firebase_screen                   object
# engagement_time_msec               int64
# button                            object
# questionnaire_type                object
# questionnaire_timestamp           object
# error                             object
# error_message                     object
# dtype: object

# %% [markdown]
# Print the column names

# %%
json_data.columns

# %%
def sort_and_group(sort_by, group_by):
    return json_data.set_index(sort_by).groupby(group_by)

# %%
users = sort_and_group('user_first_touch_timestamp','user_pseudo_id')['event_timestamp', 'user_properties']

# %%
users.mean().head()

# %%
count_per_user = users.count()

# %%
count_per_user.head()

# %%
count_per_user.event_timestamp.max().compute()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.hist(count_per_user.event_timestamp.to_dask_array(), bins=20)
plt.show()

# %%
del counts_per_user

# %%
del users

# %% [markdown]
# Now lets do some transformations like unnesting the user properties values and adding the appropriate columns

# %%
#json_data.persist()

# %%
# Currently only works for int or string values
def get_keys(json_d, keys, int_values):
    display(json_d)
    user_props_dict = dict()
    for kv in json_d.loc[0]:
        if(kv['key'] in keys):
            if(kv['key'] in int_values):
                user_props_dict[kv['key']] = int(kv['value']['int_value'])
            else:
                user_props_dict[kv['key']] = kv['value']['string_value']
    return user_props_dict

# Currently only works for int or string values
# Specify multiple keys if want to add values from 2 different columns to a single one. 
# If both contain values then returns the first one found
def get_key(json_d, keys, type_o):
    for kv in json_d:
        if(kv['key'] in keys):
            if(type_o == int):
                return int(kv['value']['int_value'])
            else:
                return kv['value']['string_value']
    
    
# Applies the lambda to each value.
project_id = json_data.user_properties.apply(lambda x: get_key(x, ['projectId'], str), meta=str)
subject_id = json_data.user_properties.apply(lambda x: get_key(x, ['subjectId'], str), meta=str)
source_id = json_data.user_properties.apply(lambda x: get_key(x, ['sourceId'], str), meta=str)
human_readable_id = json_data.user_properties.apply(lambda x: get_key(x, ['humanReadableId'], str), meta=str)
enrolment_date = json_data.user_properties.apply(lambda x: get_key(x, ['enrolmentDate'], str), meta=str)
first_open_time = json_data.user_properties.apply(lambda x: get_key(x, ['first_open_time'], int), meta=int)


# Currenlty not extracted - firebase_previous_screen, 
firebase_event_origin = json_data.event_params.apply(lambda x: get_key(x, ['firebase_event_origin'], str), meta=str)
firebase_screen = json_data.event_params.apply(lambda x: get_key(x, ['firebase_screen'], str), meta=str)
engagement_time_msec = json_data.event_params.apply(lambda x: get_key(x, ['engagement_time_msec'], int), meta=int)
button = json_data.event_params.apply(lambda x: get_key(x, ['button'], str), meta=str)
questionnaire_type = json_data.event_params.apply(lambda x: get_key(x, ['type', 'name'], str), meta=str)
questionnaire_timestamp = json_data.event_params.apply(lambda x: get_key(x, ['questionnaire_timestamp'], str), meta=str)
error = json_data.event_params.apply(lambda x: get_key(x, ['error', 'error_value'], str), meta=str)
error_message = json_data.event_params.apply(lambda x: get_key(x, ['message'], str), meta=str)

# add unnested user props
json_data = json_data.assign(project_id=project_id, subject_id=subject_id, source_id=source_id, human_readable_id=human_readable_id, enrolment_date=enrolment_date, first_open_time=first_open_time)

# add unnested event params
json_data = json_data.assign(firebase_event_origin=firebase_event_origin, firebase_screen=firebase_screen, engagement_time_msec=engagement_time_msec, button=button, questionnaire_type=questionnaire_type, questionnaire_timestamp=questionnaire_timestamp, error=error, error_message=error_message)

# %%
json_data[['subject_id','project_id', 'questionnaire_type']].head()
# Out:
#                              subject_id          project_id questionnaire_type
# 0  b7564f48-1bf4-4d9e-9925-e165a9325885  RADAR-MSDep-OSR-s1               None
# 1  b7564f48-1bf4-4d9e-9925-e165a9325885  RADAR-MSDep-OSR-s1                PDQ
# 2  b7564f48-1bf4-4d9e-9925-e165a9325885  RADAR-MSDep-OSR-s1           THINC-IT
# 3  b7564f48-1bf4-4d9e-9925-e165a9325885  RADAR-MSDep-OSR-s1     completion_log
# 4  b7564f48-1bf4-4d9e-9925-e165a9325885  RADAR-MSDep-OSR-s1     completion_log

# %%
# copy the dataframe so as to not mutate the original one
unnested_df = json_data.copy()

# %%
del json_data

# %%
# Remove the columns that have been unnested
unnested_df = unnested_df.drop(['event_params', 'user_properties'], axis=1)  #.compute()

# %%
unnested_df.head()
# Out:
#                                             app_info  \
# 0  {'id': 'org.phidatalab.radar_armt', 'version':...
# 1  {'id': 'org.phidatalab.radar_armt', 'version':...
# 2  {'id': 'org.phidatalab.radar_armt', 'version':...
# 3  {'id': 'org.phidatalab.radar_armt', 'version':...
# 4  {'id': 'org.phidatalab.radar_armt', 'version':...
#
#                                               device  \
# 0  {'category': 'mobile', 'mobile_brand_name': 'S...
# 1  {'category': 'mobile', 'mobile_brand_name': 'S...
# 2  {'category': 'mobile', 'mobile_brand_name': 'S...
# 3  {'category': 'mobile', 'mobile_brand_name': 'S...
# 4  {'category': 'mobile', 'mobile_brand_name': 'S...
#
#                  event_name  event_previous_timestamp  \
# 0  notification_rescheduled              1.557915e+15
# 1     prepared_kafka_object              1.557915e+15
# 2     prepared_kafka_object              1.558642e+15
# 3             send_to_cache              1.557915e+15
# 4             send_to_cache              1.558642e+15
#
#    event_server_timestamp_offset   event_timestamp  \
# 0                         226492  1558642464691001
# 1                         226492  1558642465541002
# 2                         226492  1558642465544003
# 3                         226492  1558642465551004
# 4                         226492  1558642465555005
#
#                                                  geo  \
# 0  {'continent': 'Europe', 'country': 'Italy', 'r...
# 1  {'continent': 'Europe', 'country': 'Italy', 'r...
# 2  {'continent': 'Europe', 'country': 'Italy', 'r...
# 3  {'continent': 'Europe', 'country': 'Italy', 'r...
# 4  {'continent': 'Europe', 'country': 'Italy', 'r...
#
#    user_first_touch_timestamp                    user_pseudo_id  \
# 0            1554974912733000  e90f9e199b8dd4f8756f46e29bc9934b
# 1            1554974912733000  e90f9e199b8dd4f8756f46e29bc9934b
# 2            1554974912733000  e90f9e199b8dd4f8756f46e29bc9934b
# 3            1554974912733000  e90f9e199b8dd4f8756f46e29bc9934b
# 4            1554974912733000  e90f9e199b8dd4f8756f46e29bc9934b
#
#            project_id  ... enrolment_date first_open_time  \
# 0  RADAR-MSDep-OSR-s1  ...  1554884949688   1554976800000
# 1  RADAR-MSDep-OSR-s1  ...  1554884949688   1554976800000
# 2  RADAR-MSDep-OSR-s1  ...  1554884949688   1554976800000
# 3  RADAR-MSDep-OSR-s1  ...  1554884949688   1554976800000
# 4  RADAR-MSDep-OSR-s1  ...  1554884949688   1554976800000
#
#   firebase_event_origin firebase_screen  engagement_time_msec button  \
# 0                   app            None                   NaN   None
# 1                   app            None                   NaN   None
# 2                   app            None                   NaN   None
# 3                   app            None                   NaN   None
# 4                   app            None                   NaN   None
#
#   questionnaire_type  questionnaire_timestamp error error_message
# 0               None                     None  None          None
# 1                PDQ            1558515600000  None          None
# 2           THINC-IT            1558515600000  None          None
# 3     completion_log            1558515600000  None          None
# 4     completion_log            1558515600000  None          None
#
# [5 rows x 23 columns]

# %%
unnested_df.dtypes

# %%
import pandas as pd

# Convert event_timestamp to datatime for timeseries analysis
unnested_df.event_timestamp = unnested_df.event_timestamp.map(lambda x: pd.to_datetime(x * 1000))

# %%
unnested_df.dtypes
# Out:
# app_info                                 object
# device                                   object
# event_name                               object
# event_previous_timestamp                float64
# event_server_timestamp_offset             int64
# event_timestamp                  datetime64[ns]
# geo                                      object
# user_first_touch_timestamp                int64
# user_pseudo_id                           object
# project_id                               object
# subject_id                               object
# source_id                                object
# human_readable_id                        object
# enrolment_date                           object
# first_open_time                           int64
# firebase_event_origin                    object
# firebase_screen                          object
# engagement_time_msec                      int64
# button                                   object
# questionnaire_type                       object
# questionnaire_timestamp                  object
# error                                    object
# error_message                            object
# dtype: object

# %%
# simple wrapper for get key that does not fail if the key does not exist
def get_dict_key(dict_d, key):
    if key in dict_d.keys():
        return dict_d[key]
    else:
        return None

# Unnest device as it contains timezone info
mobile_brand_name = unnested_df.device.apply(lambda x: get_dict_key(x, 'mobile_brand_name'), meta=str)
mobile_model_name = unnested_df.device.apply(lambda x: get_dict_key(x, 'mobile_model_name'), meta=str)
mobile_marketing_name = unnested_df.device.apply(lambda x: get_dict_key(x, 'mobile_marketing_name'), meta=str)
operating_system = unnested_df.device.apply(lambda x: get_dict_key(x, 'operating_system'), meta=str)
operating_system_version = unnested_df.device.apply(lambda x: get_dict_key(x, 'operating_system_version'), meta=str)
language = unnested_df.device.apply(lambda x: get_dict_key(x, 'language'), meta=str)
time_zone_offset_seconds = unnested_df.device.apply(lambda x: get_dict_key(x, 'time_zone_offset_seconds'), meta=str)

unnested_df = unnested_df.assign(mobile_brand_name=mobile_brand_name, mobile_model_name=mobile_model_name, mobile_marketing_name=mobile_marketing_name, operating_system=operating_system, operating_system_version=operating_system_version, language=language, time_zone_offset_seconds=time_zone_offset_seconds)
unnested_df['time_zone_offset_seconds'] = unnested_df['time_zone_offset_seconds'].astype(int)

# %%
unnested_df.dtypes
# Out:
# app_info                                 object
# device                                   object
# event_name                               object
# event_previous_timestamp                float64
# event_server_timestamp_offset             int64
# event_timestamp                  datetime64[ns]
# geo                                      object
# user_first_touch_timestamp                int64
# user_pseudo_id                           object
# project_id                               object
# subject_id                               object
# source_id                                object
# human_readable_id                        object
# enrolment_date                           object
# first_open_time                           int64
# firebase_event_origin                    object
# firebase_screen                          object
# engagement_time_msec                      int64
# button                                   object
# questionnaire_type                       object
# questionnaire_timestamp                  object
# error                                    object
# error_message                            object
# mobile_brand_name                        object
# mobile_model_name                        object
# mobile_marketing_name                    object
# operating_system                         object
# operating_system_version                 object
# language                                 object
# time_zone_offset_seconds                  int64
# event_time_of_day_UTC            datetime64[ns]
# event_time_of_day_Local          datetime64[ns]
# dtype: object

# %%
# Calculate Time of Day in UTC 
def get_time_of_day(event_time, timezone_offset_in_seconds):
    if event_time is not None and timezone_offset_in_seconds is not None:
        event_time = event_time + pd.Timedelta(seconds=timezone_offset_in_seconds)
        y = event_time - event_time.normalize()
        return y
    else:
        return np.NaN
    
unnested_df['event_time_of_day_UTC'] = unnested_df.event_timestamp.apply(lambda x: get_time_of_day(x, 0), meta=('datetime64[ns]'))

# Calculate time of day in Local Time by applying row-wise (axis =1)
unnested_df['event_time_of_day_Local'] = unnested_df.apply(lambda x: get_time_of_day(x.get('event_timestamp'), int(x.get('time_zone_offset_seconds'))), axis=1, meta=('datetime64[ns]'))

# Calculate Local location

# %%
unnested_df[unnested_df['time_zone_offset_seconds'] < 0]

# %%
type(unnested_df[time_zone_offset_seconds])

# %%
import numpy as np

unnested_df[unnested_df['engagement_time_msec'].isnull().apply(lambda x: not x)]
# Out:
# /anaconda3/lib/python3.7/site-packages/dask/dataframe/core.py:2285: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   warnings.warn(msg)
# Dask DataFrame Structure:
#               app_info  device event_name event_previous_timestamp event_server_timestamp_offset event_timestamp     geo user_first_touch_timestamp user_pseudo_id project_id subject_id source_id human_readable_id enrolment_date first_open_time firebase_event_origin firebase_screen engagement_time_msec  button questionnaire_type questionnaire_timestamp   error error_message mobile_brand_name mobile_model_name mobile_marketing_name operating_system operating_system_version language time_zone_offset_seconds event_time_of_day_UTC event_time_of_day_Local
# npartitions=1
#                 object  object     object                  float64                         int64  datetime64[ns]  object                      int64         object     object     object    object            object         object           int64                object          object                int64  object             object                  object  object        object            object            object                object           object                   object   object                    int64        datetime64[ns]          datetime64[ns]
#                    ...     ...        ...                      ...                           ...             ...     ...                        ...            ...        ...        ...       ...               ...            ...             ...                   ...             ...                  ...     ...                ...                     ...     ...           ...               ...               ...                   ...              ...                      ...      ...                      ...                   ...                     ...
# Dask Name: getitem, 50 tasks

# %%
event_time_of_day_UTC.sort_values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a866736f5a47> in <module>
# ----> 1 event_time_of_day_UTC.sort_values()
#
# NameError: name 'event_time_of_day_UTC' is not defined

# %%
event_time_of_day_Local.sort_values()

# %%
# Select the engagement time (not null) and column of the day

local_time_engagement = unnested_df[unnested_df['engagement_time_msec'].apply(lambda x: x is not None and x < 1000000)][['event_timestamp', 'event_time_of_day_Local', 'engagement_time_msec', 'project_id', 'subject_id', 'user_pseudo_id']]
# Out:
# /anaconda3/lib/python3.7/site-packages/dask/dataframe/core.py:2285: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   warnings.warn(msg)

# %%
local_time_engagement = local_time_engagement.compute().set_index('event_time_of_day_Local')

# %%
local_time_engagement['engagement_time_msec'] = local_time_engagement['engagement_time_msec']

# %%
import seaborn
seaborn.set(style='ticks')

# %%
local_time_engagement.resample('1H').sum().plot(kind='bar')
plt.ylabel('Aggregate Engagement Time of the users')
plt.xlabel('Time of the Day in Local Timezone')
plt.savefig('engagement_time_distribution_2.png')
plt.show()

# %%
# fg = seaborn.FacetGrid(data=local_time_engagement.groupby('project_id').resample('1H').sum(), hue='project_id', height=2.5, aspect=2.5)
# fg.map(plt.line, 'event_time_of_day_Local', 'engagement_time_msec').add_legend()

seaborn.catplot(x="'event_time_of_day_Local'", y="engagement_time_msec", data=local_time_engagement.groupby('project_id').resample('1H').sum());
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-325e9f368270> in <module>
#       2 # fg.map(plt.line, 'event_time_of_day_Local', 'engagement_time_msec').add_legend()
#       3
# ----> 4 seaborn.catplot(x="'event_time_of_day_Local'", y="engagement_time_msec", data=local_time_engagement.groupby('project_id').resample('1H').sum());
#
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3714     # facets to ensure representation of all data in the final plot
#    3715     p = _CategoricalPlotter()
# -> 3716     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3717     order = p.group_names
#    3718     hue_order = p.hue_names
#
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input ''event_time_of_day_Local''

# %%
local_time_engagement['event_time_of_day_Local'] = local_time_engagement.index.seconds.values / 60 / 60

# %%
fg = seaborn.FacetGrid(data=local_time_engagement, hue='project_id', height=2.5, aspect=2.5)
fg.map(plt.scatter, 'event_time_of_day_Local', 'engagement_time_msec').add_legend()

# %%
# fig = local_time_engagement.groupby('project_id').resample('1H').sum().plot(kind='bar', subplots=True)
# plt.ylabel('Aggregate Engagement Time of the users')
# plt.xlabel('Time of the Day in Local Timezone')
# plt.show()


grouped = local_time_engagement.groupby('project_id')
# rowlength = int(grouped.ngroups/2)                         # fix up if odd number of groups
# fig, axs = plt.subplots(figsize=(9,4), 
#                         nrows=2, ncols=rowlength,     # fix as above
#                         gridspec_kw=dict(hspace=0.4)) # Much control of gridspec

# targets = zip(grouped.groups.keys(), axs.flatten())
for key, group in grouped:
    print(type(grouped.get_group(key)))
    fig = grouped.get_group(key).resample('1H').sum().plot(kind='bar', title='%s'%key)
    #ax.plot(grouped.get_group(key))
#     ax.set_title('a=%s'%key)
# ax.legend()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
local_time_engagement.head()
# Out:
#                                    event_timestamp  engagement_time_msec  \
# event_time_of_day_Local
# 22:16:48.132009         2019-05-23 20:16:48.132009               91708.0
# 22:16:54.237014         2019-05-23 20:16:54.237014                6103.0
# 22:17:25.267017         2019-05-23 20:17:25.267017               31031.0
# 22:17:55.783021         2019-05-23 20:17:55.783021               15057.0
# 14:07:13.116004         2019-05-23 12:07:13.116004                4229.0
#
#                                  project_id  \
# event_time_of_day_Local
# 22:16:48.132009          RADAR-MSDep-OSR-s1
# 22:16:54.237014          RADAR-MSDep-OSR-s1
# 22:17:25.267017          RADAR-MSDep-OSR-s1
# 22:17:55.783021          RADAR-MSDep-OSR-s1
# 14:07:13.116004          RADAR-MSDis-OSR-s1
#
#                                                    subject_id  \
# event_time_of_day_Local
# 22:16:48.132009          b7564f48-1bf4-4d9e-9925-e165a9325885
# 22:16:54.237014          b7564f48-1bf4-4d9e-9925-e165a9325885
# 22:17:25.267017          b7564f48-1bf4-4d9e-9925-e165a9325885
# 22:17:55.783021          b7564f48-1bf4-4d9e-9925-e165a9325885
# 14:07:13.116004          4581e73e-5bcf-45bf-b724-446b5910a23f
#
#                                            user_pseudo_id  \
# event_time_of_day_Local
# 22:16:48.132009          e90f9e199b8dd4f8756f46e29bc9934b
# 22:16:54.237014          e90f9e199b8dd4f8756f46e29bc9934b
# 22:17:25.267017          e90f9e199b8dd4f8756f46e29bc9934b
# 22:17:55.783021          e90f9e199b8dd4f8756f46e29bc9934b
# 14:07:13.116004          a2878cf66bf946623f92c74d66eeefdb
#
#                          event_time_of_day_Local
# event_time_of_day_Local
# 22:16:48.132009                        22.280000
# 22:16:54.237014                        22.281667
# 22:17:25.267017                        22.290278
# 22:17:55.783021                        22.298611
# 14:07:13.116004                        14.120278

# %%
project = 'RADAR-MDD-CIBER-s1'
grouped_subject = local_time_engagement[local_time_engagement['project_id'] == project].groupby('subject_id')
base_path = 'plots/%s/subjects/engagement_patterns/' % project
import os
if not os.path.exists(base_path):
    os.makedirs(base_path)
    
date_time_interval = pd.timedelta_range(start='0 day', end='1 day', freq='1H')
for key, group in grouped_subject:
    count= pd.DataFrame()
    count['count'] = grouped_subject.get_group(key).resample('H').count()['subject_id']
    plt.figure()
    fig = grouped_subject.get_group(key).resample('H').sum().join(count).plot(kind='bar', title='%s'%key, secondary_y='count')
    plt.savefig('%s/%s.png' % (base_path, key), bbox_inches="tight")
# plt.show()

# %%
notification_data = unnested_df[unnested_df['firebase_event_origin'] == 'fcm'][['event_name', 'event_timestamp', 'event_time_of_day_Local' , 'project_id', 'subject_id', 'enrolment_date', 'user_pseudo_id']].compute()

# %%
notification_data['event_time_of_day_Local_s'] = notification_data['event_time_of_day_Local'] / np.timedelta64(1, 's')

# %%
notification_data = notification_data.set_index('event_time_of_day_Local')

# %%
notification_data.groupby('project_id')

# %%
grouped = notification_data.groupby('project_id')
for key, group in grouped:
    group_df = grouped.get_group(key)
    print(group_df[group_df['event_name'] == 'notification_receive'].resample('1H').count().head())
    fig = group_df[group_df['event_name'] == 'notification_receive'].resample('1H').count().plot(kind='bar', title='%s'%key)
plt.show()
# Out:
#                          event_name  event_timestamp  project_id  subject_id  \
# event_time_of_day_Local
# 10:00:07.152000                   2                2           2           2
# 11:00:07.152000                   1                1           1           1
# 12:00:07.152000                   0                0           0           0
# 13:00:07.152000                   1                1           1           1
#
#                          enrolment_date  user_pseudo_id  \
# event_time_of_day_Local
# 10:00:07.152000                       2               2
# 11:00:07.152000                       1               1
# 12:00:07.152000                       0               0
# 13:00:07.152000                       1               1
#
#                          event_time_of_day_Local_s
# event_time_of_day_Local
# 10:00:07.152000                                  2
# 11:00:07.152000                                  1
# 12:00:07.152000                                  0
# 13:00:07.152000                                  1
#                          event_name  event_timestamp  project_id  subject_id  \
# event_time_of_day_Local
# 08:37:07.989000                   4                4           4           4
# 09:37:07.989000                   4                4           4           4
# 10:37:07.989000                   9                9           9           9
# 11:37:07.989000                   2                2           2           2
# 12:37:07.989000                   6                6           6           6
#
#                          enrolment_date  user_pseudo_id  \
# event_time_of_day_Local
# 08:37:07.989000                       4               4
# 09:37:07.989000                       4               4
# 10:37:07.989000                       9               9
# 11:37:07.989000                       2               2
# 12:37:07.989000                       6               6
#
#                          event_time_of_day_Local_s
# event_time_of_day_Local
# 08:37:07.989000                                  4
# 09:37:07.989000                                  4
# 10:37:07.989000                                  9
# 11:37:07.989000                                  2
# 12:37:07.989000                                  6
#                          event_name  event_timestamp  project_id  subject_id  \
# event_time_of_day_Local
# 00:14:13.738000                   1                1           1           1
# 01:14:13.738000                   0                0           0           0
# 02:14:13.738000                   1                1           1           1
# 03:14:13.738000                   0                0           0           0
# 04:14:13.738000                   0                0           0           0
#
#                          enrolment_date  user_pseudo_id  \
# event_time_of_day_Local
# 00:14:13.738000                       1               1
# 01:14:13.738000                       0               0
# 02:14:13.738000                       1               1
# 03:14:13.738000                       0               0
# 04:14:13.738000                       0               0
#
#                          event_time_of_day_Local_s
# event_time_of_day_Local
# 00:14:13.738000                                  1
# 01:14:13.738000                                  0
# 02:14:13.738000                                  1
# 03:14:13.738000                                  0
# 04:14:13.738000                                  0
#                          event_name  event_timestamp  project_id  subject_id  \
# event_time_of_day_Local
# 04:34:45.905000                   3                3           3           3
# 05:34:45.905000                   0                0           0           0
# 06:34:45.905000                  10               10          10          10
# 07:34:45.905000                  10               10          10          10
# 08:34:45.905000                 230              230         230         230
#
#                          enrolment_date  user_pseudo_id  \
# event_time_of_day_Local
# 04:34:45.905000                       3               3
# 05:34:45.905000                       0               0
# 06:34:45.905000                      10              10
# 07:34:45.905000                      10              10
# 08:34:45.905000                     230             230
#
#                          event_time_of_day_Local_s
# event_time_of_day_Local
# 04:34:45.905000                                  3
# 05:34:45.905000                                  0
# 06:34:45.905000                                 10
# 07:34:45.905000                                 10
# 08:34:45.905000                                230
#                          event_name  event_timestamp  project_id  subject_id  \
# event_time_of_day_Local
# 09:00:00.392000                  29               29          29          29
# 10:00:00.392000                   2                2           2           2
# 11:00:00.392000                   0                0           0           0
# 12:00:00.392000                   0                0           0           0
# 13:00:00.392000                   0                0           0           0
#
#                          enrolment_date  user_pseudo_id  \
# event_time_of_day_Local
# 09:00:00.392000                      29              29
# 10:00:00.392000                       2               2
# 11:00:00.392000                       0               0
# 12:00:00.392000                       0               0
# 13:00:00.392000                       0               0
#
#                          event_time_of_day_Local_s
# event_time_of_day_Local
# 09:00:00.392000                                 29
# 10:00:00.392000                                  2
# 11:00:00.392000                                  0
# 12:00:00.392000                                  0
# 13:00:00.392000                                  0
#                          event_name  event_timestamp  project_id  subject_id  \
# event_time_of_day_Local
# 00:11:23.052000                   1                1           1           1
# 01:11:23.052000                   0                0           0           0
# 02:11:23.052000                   0                0           0           0
# 03:11:23.052000                   0                0           0           0
# 04:11:23.052000                   0                0           0           0
#
#                          enrolment_date  user_pseudo_id  \
# event_time_of_day_Local
# 00:11:23.052000                       1               1
# 01:11:23.052000                       0               0
# 02:11:23.052000                       0               0
# 03:11:23.052000                       0               0
# 04:11:23.052000                       0               0
#
#                          event_time_of_day_Local_s
# event_time_of_day_Local
# 00:11:23.052000                                  1
# 01:11:23.052000                                  0
# 02:11:23.052000                                  0
# 03:11:23.052000                                  0
# 04:11:23.052000                                  0
#                          event_name  event_timestamp  project_id  subject_id  \
# event_time_of_day_Local
# 11:00:07.454000                   3                3           3           3
#
#                          enrolment_date  user_pseudo_id  \
# event_time_of_day_Local
# 11:00:07.454000                       3               3
#
#                          event_time_of_day_Local_s
# event_time_of_day_Local
# 11:00:07.454000                                  3
#                          event_name  event_timestamp  project_id  subject_id  \
# event_time_of_day_Local
# 10:00:03.358000                   3                3           3           3
# 11:00:03.358000                  11               11          11          11
#
#                          enrolment_date  user_pseudo_id  \
# event_time_of_day_Local
# 10:00:03.358000                       3               3
# 11:00:03.358000                      11              11
#
#                          event_time_of_day_Local_s
# event_time_of_day_Local
# 10:00:03.358000                                  3
# 11:00:03.358000                                 11
#                          event_name  event_timestamp  project_id  subject_id  \
# event_time_of_day_Local
# 06:47:20.971000                  23               23          23          23
# 07:47:20.971000                   3                3           3           3
# 08:47:20.971000                  29               29          29          29
# 09:47:20.971000                  66               66          66          66
# 10:47:20.971000                 196              196         196         196
#
#                          enrolment_date  user_pseudo_id  \
# event_time_of_day_Local
# 06:47:20.971000                      23              23
# 07:47:20.971000                       3               3
# 08:47:20.971000                      29              29
# 09:47:20.971000                      66              66
# 10:47:20.971000                     196             196
#
#                          event_time_of_day_Local_s
# event_time_of_day_Local
# 06:47:20.971000                                 23
# 07:47:20.971000                                  3
# 08:47:20.971000                                 29
# 09:47:20.971000                                 66
# 10:47:20.971000                                196
#                          event_name  event_timestamp  project_id  subject_id  \
# event_time_of_day_Local
# 06:22:51.320000                   1                1           1           1
# 07:22:51.320000                   9                9           9           9
# 08:22:51.320000                   8                8           8           8
# 09:22:51.320000                  19               19          19          19
# 10:22:51.320000                  31               31          31          31
#
#                          enrolment_date  user_pseudo_id  \
# event_time_of_day_Local
# 06:22:51.320000                       1               1
# 07:22:51.320000                       9               9
# 08:22:51.320000                       8               8
# 09:22:51.320000                      19              19
# 10:22:51.320000                      31              31
#
#                          event_time_of_day_Local_s
# event_time_of_day_Local
# 06:22:51.320000                                  1
# 07:22:51.320000                                  9
# 08:22:51.320000                                  8
# 09:22:51.320000                                 19
# 10:22:51.320000                                 31
#                          event_name  event_timestamp  project_id  subject_id  \
# event_time_of_day_Local
# 07:30:01.478000                  10               10          10          10
# 08:30:01.478000                   7                7           7           7
# 09:30:01.478000                  48               48          48          48
# 10:30:01.478000                  37               37          37          37
# 11:30:01.478000                 196              196         196         196
#
#                          enrolment_date  user_pseudo_id  \
# event_time_of_day_Local
# 07:30:01.478000                      10              10
# 08:30:01.478000                       7               7
# 09:30:01.478000                      48              48
# 10:30:01.478000                      37              37
# 11:30:01.478000                     196             196
#
#                          event_time_of_day_Local_s
# event_time_of_day_Local
# 07:30:01.478000                                 10
# 08:30:01.478000                                  7
# 09:30:01.478000                                 48
# 10:30:01.478000                                 37
# 11:30:01.478000                                196
#                          event_name  event_timestamp  project_id  subject_id  \
# event_time_of_day_Local
# 09:00:02.573000                  10               10          10          10
# 10:00:02.573000                  20               20          20          20
# 11:00:02.573000                  22               22          22          22
# 12:00:02.573000                   8                8           8           8
# 13:00:02.573000                   9                9           9           9
#
#                          enrolment_date  user_pseudo_id  \
# event_time_of_day_Local
# 09:00:02.573000                      10              10
# 10:00:02.573000                      20              20
# 11:00:02.573000                      22              22
# 12:00:02.573000                       8               8
# 13:00:02.573000                       9               9
#
#                          event_time_of_day_Local_s
# event_time_of_day_Local
# 09:00:02.573000                                 10
# 10:00:02.573000                                 20
# 11:00:02.573000                                 22
# 12:00:02.573000                                  8
# 13:00:02.573000                                  9
#                          event_name  event_timestamp  project_id  subject_id  \
# event_time_of_day_Local
# 08:30:01.668000                   4                4           4           4
# 09:30:01.668000                  10               10          10          10
# 10:30:01.668000                   0                0           0           0
# 11:30:01.668000                   4                4           4           4
# 12:30:01.668000                   5                5           5           5
#
#                          enrolment_date  user_pseudo_id  \
# event_time_of_day_Local
# 08:30:01.668000                       4               4
# 09:30:01.668000                      10              10
# 10:30:01.668000                       0               0
# 11:30:01.668000                       4               4
# 12:30:01.668000                       5               5
#
#                          event_time_of_day_Local_s
# event_time_of_day_Local
# 08:30:01.668000                                  4
# 09:30:01.668000                                 10
# 10:30:01.668000                                  0
# 11:30:01.668000                                  4
# 12:30:01.668000                                  5

# %%
seaborn.pairplot(local_time_engagement.query('not project_id.isnull() and not subject_id.isnull()'), vars=['project_id', 'subject_id', 'event_time_of_day_Local', 'engagement_time_msec'], dropna=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-04d5ff631a9e> in <module>
# ----> 1 seaborn.pairplot(local_time_engagement.query('not project_id.isnull() and not subject_id.isnull()'), vars=['project_id', 'subject_id', 'event_time_of_day_Local', 'engagement_time_msec'], dropna=True)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    3086         kwargs['level'] = kwargs.pop('level', 0) + 1
#    3087         kwargs['target'] = None
# -> 3088         res = self.eval(expr, **kwargs)
#    3089
#    3090         try:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    3201             kwargs['target'] = self
#    3202         kwargs['resolvers'] = kwargs.get('resolvers', ()) + tuple(resolvers)
# -> 3203         return _eval(expr, inplace=inplace, **kwargs)
#    3204
#    3205     def select_dtypes(self, include=None, exclude=None):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     297         eng = _engines[engine]
#     298         eng_inst = eng(parsed_expr)
# --> 299         ret = eng_inst.evaluate()
#     300
#     301         if parsed_expr.assigner is None:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/computation/engines.py in evaluate(self)
#      74
#      75         # make sure no names in resolvers and locals/globals clash
# ---> 76         res = self._evaluate()
#      77         return _reconstruct_object(self.result_type, res, self.aligned_axes,
#      78                                    self.expr.terms.return_type)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/computation/engines.py in _evaluate(self)
#     120             scope = env.full_scope
#     121             truediv = scope['truediv']
# --> 122             _check_ne_builtin_clash(self.expr)
#     123             return ne.evaluate(s, local_dict=scope, truediv=truediv)
#     124         except KeyError as e:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/computation/engines.py in _check_ne_builtin_clash(expr)
#      29         Terms can contain
#      30     """
# ---> 31     names = expr.names
#      32     overlap = names & _ne_builtins
#      33
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/computation/expr.py in names(self)
#     771         if is_term(self.terms):
#     772             return frozenset([self.terms.name])
# --> 773         return frozenset(term.name for term in com.flatten(self.terms))
#     774
#     775
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
local_time_engagement.index
# Out:
# TimedeltaIndex(['22:16:48.132009', '22:16:54.237014', '22:17:25.267017',
#                 '22:17:55.783021', '14:07:13.116004', '14:08:20.679004',
#                 '14:08:25.485005', '11:31:02.463008', '11:31:59.392009',
#                 '11:32:04.764014',
#                 ...
#                 '10:08:23.829058', '10:08:47.276060', '10:08:57.208064',
#                 '12:07:00.365004', '06:45:40.020001', '23:34:54.561012',
#                 '22:44:19.629006', '23:38:40.215000', '18:25:26.182003',
#                 '18:25:45.587009'],
#                dtype='timedelta64[ns]', name='event_time_of_day_Local', length=11991, freq=None)

# %%
local_time_engagement[['event_time_of_day_Local', 'engagement_time_msec']].corr()
# Out:
#                          event_time_of_day_Local  engagement_time_msec
# event_time_of_day_Local                 1.000000             -0.016161
# engagement_time_msec                   -0.016161              1.000000

# %%
local_time_engagement.head()
# Out:
#                          engagement_time_msec          project_id  \
# event_time_of_day_Local
# 22:16:48.132009                       91708.0  RADAR-MSDep-OSR-s1
# 22:16:54.237014                        6103.0  RADAR-MSDep-OSR-s1
# 22:17:25.267017                       31031.0  RADAR-MSDep-OSR-s1
# 22:17:55.783021                       15057.0  RADAR-MSDep-OSR-s1
# 14:07:13.116004                        4229.0  RADAR-MSDis-OSR-s1
#
#                                                    subject_id  \
# event_time_of_day_Local
# 22:16:48.132009          b7564f48-1bf4-4d9e-9925-e165a9325885
# 22:16:54.237014          b7564f48-1bf4-4d9e-9925-e165a9325885
# 22:17:25.267017          b7564f48-1bf4-4d9e-9925-e165a9325885
# 22:17:55.783021          b7564f48-1bf4-4d9e-9925-e165a9325885
# 14:07:13.116004          4581e73e-5bcf-45bf-b724-446b5910a23f
#
#                                            user_pseudo_id
# event_time_of_day_Local
# 22:16:48.132009          e90f9e199b8dd4f8756f46e29bc9934b
# 22:16:54.237014          e90f9e199b8dd4f8756f46e29bc9934b
# 22:17:25.267017          e90f9e199b8dd4f8756f46e29bc9934b
# 22:17:55.783021          e90f9e199b8dd4f8756f46e29bc9934b
# 14:07:13.116004          a2878cf66bf946623f92c74d66eeefdb

# %%
# ?grouped_by_subject_id

# %%
# ?local_time_engagement.groupby

# %%
dask_df = df.from_pandas(local_time_engagement, npartitions=1)
local_time_engagement.groupby('project_id').resample('1H').mean().unstack(level=0).plot(kind='bar', subplots=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-9ea50f8a9b72> in <module>
#       1 dask_df = df.from_pandas(local_time_engagement, npartitions=1)
# ----> 2 local_time_engagement.resample('1H', level='project_id').mean().unstack(level=0).plot(kind='bar', subplots=True)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    8153                      axis=axis, kind=kind, loffset=loffset,
#    8154                      convention=convention,
# -> 8155                      base=base, key=on, level=level)
#    8156         return _maybe_process_deprecations(r,
#    8157                                            how=how,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/resample.py in resample(obj, kind, **kwds)
#    1248     """
#    1249     tg = TimeGrouper(**kwds)
# -> 1250     return tg._get_resampler(obj, kind=kind)
#    1251
#    1252
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
#    1358
#    1359         """
# -> 1360         self._set_grouper(obj)
#    1361
#    1362         ax = self.ax
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in _set_grouper(self, obj, sort)
#     178                     if level not in (0, ax.name):
#     179                         raise ValueError(
# --> 180                             "The level {0} is not valid".format(level))
#     181
#     182         # possibly sort
#
# ValueError: The level project_id is not valid

# %%
# ?plt.bar

# %%
dask_df = df.from_pandas(local_time_engagement)
dask_df.groupby('project_id').plot( kind='line')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2c7adc485fe6> in <module>
# ----> 1 dask_df = df.from_pandas(local_time_engagement)
#       2 dask_df.groupby('project_id').plot( kind='line')
#
# NameError: name 'df' is not defined

# %%
client.cancel(unnested_df)

# %%
# Reset the client and delete all variables from the distributed cluter
client.restart()
